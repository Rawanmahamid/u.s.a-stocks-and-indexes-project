# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
from iexfinance.stocks import get_historical_data
from iexfinance.stocks import Stock
import os
from yahoofinancials import YahooFinancials

# %%
start_date = '2000-01-01'
end_date = '2020-11-01'
panel_data = web.DataReader(xxx,'yahoo', start_date, end_date)
panel_data[['Close','Volume']].to_excel('Nasdaq.xlsx')
# Out:
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ABAC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ABCW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ABDC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ABGB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
sym=pd.read_csv('./Downloads/./Dow jones.csv')
xxx=sym['Symbol']

# %%
    dd=web.DataReader('axp', 'yahoo-actions',start='2000-01-01',end='2020-11-01')
    dd
    # returns dividend history for ticker PFF
# Out:
#               action     value
# 2020-10-08  DIVIDEND  0.430000
# 2020-07-01  DIVIDEND  0.430000
# 2020-04-02  DIVIDEND  0.430000
# 2020-01-02  DIVIDEND  0.430000
# 2019-10-03  DIVIDEND  0.430000
# ...              ...       ...
# 2000-10-04  DIVIDEND  0.070020
# 2000-07-05  DIVIDEND  0.070020
# 2000-05-11     SPLIT  0.333333
# 2000-04-20  DIVIDEND  0.070020
# 2000-01-05  DIVIDEND  0.065650
#
# [86 rows x 2 columns]

# %%
yyy=pd.unique(xxx)
zzz=list(yyy)
zzz
# Out:
# ['AAPl',
#  'AMGN',
#  'AXP',
#  'BA',
#  'CAT',
#  'CRM',
#  'CSCO',
#  'CVX',
#  'DIS',
#  'GE',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'KO',
#  'MCD',
#  'MMM',
#  'MRK',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'V',
#  'VZ',
#  'WMT',
#  'DD']

# %%
for i in range(len(zzz)):
    xx=web.DataReader(zzz[i], 'yahoo-actions',start='2000-01-01',end='2020-11-01')

# %%
ddd.to_excel('DD.xlsx')
