# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
from iexfinance.stocks import get_historical_data
from iexfinance.stocks import Stock
import os
from yahoofinancials import YahooFinancials

# %%
sympols=pd.read_excel('./Downloads./symbolssp400.xlsx')
sympols
# Out:
#     Symbol
# 0      AAN
# 1     AAXN
# 2      ACC
# 3     ACHC
# 4     ACIW
# ..     ...
# 383      X
# 384    XEC
# 385    XPO
# 386      Y
# 387   YELP
#
# [388 rows x 1 columns]

# %%
y=sympols['Symbol'].str.startswith('W',na=True)

# %%
ll=list(sympols['Symbol'])
ll
# Out:
# ['AAN',
#  'AAXN',
#  'ACC',
#  'ACHC',
#  'ACIW',
#  'ACM',
#  'ADNT',
#  'AEO',
#  'AFG',
#  'AGCO',
#  'AKRX',
#  'ALE',
#  'AM',
#  'AMCX',
#  'AMED',
#  'AMG',
#  'AN',
#  'APY',
#  'ARW',
#  'ARWR',
#  'ASB',
#  'ASGN',
#  'ASH',
#  'ATGE',
#  'ATI',
#  'ATR',
#  'AVNS',
#  'AVT',
#  'AYI',
#  'BBBY',
#  'BC',
#  'BCO',
#  'BDC',
#  'BHF',
#  'BID',
#  'BJ',
#  'BKH',
#  'BLKB',
#  'BOH',
#  'BRO',
#  'BRX',
#  'BXS',
#  'BYD',
#  'CABO',
#  'CACI',
#  'CAKE',
#  'CAR',
#  'CASY',
#  'CATY',
#  'CBRL',
#  'CBSH',
#  'CBT',
#  'CC',
#  'CCMP',
#  'CDAY',
#  'CDK',
#  'CFR',
#  'CFX',
#  'CGNX',
#  'CHDN',
#  'CHE',
#  'CHH',
#  'CIEN',
#  'CIT',
#  'CLB',
#  'CLGX',
#  'CLH',
#  'CLI',
#  'CMC',
#  'CMD',
#  'CMP',
#  'CNK',
#  'CNO',
#  'CNX',
#  'COHR',
#  'COLM',
#  'CONE',
#  'COR',
#  'CPT',
#  'CR',
#  'CREE',
#  'CRI',
#  'CRL',
#  'CRS',
#  'CRUS',
#  'CSL',
#  'CUZ',
#  'CVLT',
#  'CW',
#  'CXW',
#  'CZR',
#  'DAN',
#  'DAR',
#  'DCI',
#  'DDS',
#  'DECK',
#  'DEI',
#  'DKS',
#  'DLPH',
#  'DLX',
#  'DNKN',
#  'DNOW',
#  'DY',
#  'EAT',
#  'EGP',
#  'EHC',
#  'EME',
#  'ENR',
#  'ENS',
#  'EPC',
#  'EPR',
#  'EQT',
#  'ERI',
#  'ETRN',
#  'EV',
#  'EVR',
#  'EWBC',
#  'EXEL',
#  'EXP',
#  'FAF',
#  'FCFS',
#  'FCN',
#  'FDS',
#  'FFIN',
#  'FHN',
#  'FICO',
#  'FII',
#  'FIVE',
#  'FL',
#  'FLO',
#  'FLR',
#  'FNB',
#  'FR',
#  'FSLR',
#  'FULT',
#  'GATX',
#  'GEF',
#  'GEO',
#  'GGG',
#  'GHC',
#  'GME',
#  'GMED',
#  'GNRC',
#  'GNTX',
#  'GNW',
#  'GRUB',
#  'GT',
#  'HAE',
#  'HAIN',
#  'HCSG',
#  'HE',
#  'HELE',
#  'HIW',
#  'HNI',
#  'HOMB',
#  'HPT',
#  'HQY',
#  'HR',
#  'HRC',
#  'HUBB',
#  'HWC',
#  'IART',
#  'IBKR',
#  'IBOC',
#  'ICUI',
#  'IDA',
#  'IDCC',
#  'IIVI',
#  'INGR',
#  'INT',
#  'ISCA',
#  'ITT',
#  'JACK',
#  'JBGS',
#  'JBL',
#  'JBLU',
#  'JCOM',
#  'JEF',
#  'JHG',
#  'JLL',
#  'JW.A',
#  'KAR',
#  'KBH',
#  'KBR',
#  'KEX',
#  'KMPR',
#  'KMT',
#  'KNX',
#  'KRC',
#  'LAMR',
#  'LANC',
#  'LEA',
#  'LECO',
#  'LFUS',
#  'LGND',
#  'LHCG',
#  'LII',
#  'LITE',
#  'LIVN',
#  'LM',
#  'LOPE',
#  'LPX',
#  'LSI',
#  'LSTR',
#  'MAC',
#  'MAN',
#  'MANH',
#  'MASI',
#  'MAT',
#  'MCY',
#  'MD',
#  'MDP',
#  'MDRX',
#  'MDU',
#  'MKSI',
#  'MLHR',
#  'MMS',
#  'MOH',
#  'MPW',
#  'MPWR',
#  'MSA',
#  'MSM',
#  'MTDR',
#  'MTX',
#  'MTZ',
#  'MUR',
#  'MUSA',
#  'NATI',
#  'NAVI',
#  'NCR',
#  'NDSN',
#  'NEU',
#  'NFG',
#  'NGVT',
#  'NJR',
#  'NNN',
#  'NSP',
#  'NTCT',
#  'NUS',
#  'NUVA',
#  'NVT',
#  'NWE',
#  'NYCB',
#  'NYT',
#  'OC',
#  'ODP',
#  'OFC',
#  'OGE',
#  'OGS',
#  'OHI',
#  'OI',
#  'OLED',
#  'OLLI',
#  'OLN',
#  'ORI',
#  'OSK',
#  'OZK',
#  'PACW',
#  'PB',
#  'PBF',
#  'PBH',
#  'PCH',
#  'PDCO',
#  'PEB',
#  'PEN',
#  'PENN',
#  'PII',
#  'PK',
#  'PNFP',
#  'PNM',
#  'POL',
#  'POST',
#  'PPC',
#  'PRAH',
#  'PRI',
#  'PSB',
#  'PTC',
#  'PTEN',
#  'PZZA',
#  'R',
#  'RAMP',
#  'RBC',
#  'RGA',
#  'RGEN',
#  'RGLD',
#  'RH',
#  'RIG',
#  'RNR',
#  'RPM',
#  'RS',
#  'RYN',
#  'SABR',
#  'SAFM',
#  'SAIC',
#  'SAM',
#  'SBH',
#  'SBNY',
#  'SBRA',
#  'SCI',
#  'SEIC',
#  'SF',
#  'SFM',
#  'SGMS',
#  'SIGI',
#  'SIX',
#  'SKX',
#  'SLAB',
#  'SLGN',
#  'SLM',
#  'SMG',
#  'SMTC',
#  'SNH',
#  'SNV',
#  'SNX',
#  'SON',
#  'SRC',
#  'SRCL',
#  'STL',
#  'STLD',
#  'SWX',
#  'SXT',
#  'SYNA',
#  'SYNH',
#  'TCBI',
#  'TCO',
#  'TDC',
#  'TDS',
#  'TECD',
#  'TECH',
#  'TEX',
#  'TGNA',
#  'THC',
#  'THG',
#  'THO',
#  'THS',
#  'TKR',
#  'TMHC',
#  'TOL',
#  'TPH',
#  'TPX',
#  'TR',
#  'TREE',
#  'TREX',
#  'TRIP',
#  'TRMB',
#  'TRMK',
#  'TRN',
#  'TTC',
#  'TTEK',
#  'TXRH',
#  'UBSI',
#  'UE',
#  'UFS',
#  'UGI',
#  'UMBF',
#  'UMPQ',
#  'UNFI',
#  'URBN',
#  'UTHR',
#  'VAC',
#  'VC',
#  'VLY',
#  'VMI',
#  'VSAT',
#  'VSH',
#  'VSM',
#  'VVV',
#  'WAFD',
#  'WBS',
#  'WEN',
#  'WERN',
#  'WEX',
#  'WOR',
#  'WPX',
#  'WRI',
#  'WSM',
#  'WSO',
#  'WTFC',
#  'WTRG',
#  'WW',
#  'WWD',
#  'WWE',
#  'WYND',
#  'X',
#  'XEC',
#  'XPO',
#  'Y',
#  'YELP']

# %%
start_date = '2000-01-01'
end_date = '2020-11-01'
panel_data = web.DataReader(ll,'yahoo', start_date, end_date)
panel_data.to_excel('sp400.xlsx')
# Out:
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'AKRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'APY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'BID', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'FII', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'HPT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ISCA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'JW.A', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'SNH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'VSM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
