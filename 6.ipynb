# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
from iexfinance.stocks import get_historical_data
from iexfinance.stocks import Stock
import os
from yahoofinancials import YahooFinancials as yfs
import yfinance as yf

# %%
un=pd.unique(sympols2['Symbol'])
symm2=list(un)
symm2

start =('2000-01-01')
end =('2020-11-01')
a=pd.concat(web.DataReader(symm2,'yahoo-actions','2000-1-1','2020-11-1'))
a.to_excel('nasdaqqqa.xlsx')

# %%
un=pd.unique(sympols3['Symbol'])
symm3=list(un)
symm3

start =('2000-01-01')
end =('2020-11-01')
b=pd.concat(web.DataReader(symm3,'yahoo-actions','2000-1-1','2020-11-1'))
b.to_excel('nasdaqqqb.xlsx')
# Out:
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NBTB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NDSN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NEOG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NICE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NICK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NKSH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NKTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NNBR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NRIM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NSEC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NSIT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NSSC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NSYS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NTAP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NTCT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NTIC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NTRS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NTWK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NUAN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NVAX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NVDA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NVEC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NWBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NWFL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NWLI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NWPX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'NYMX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
un=pd.unique(sympols4['Symbol'])
symm4=list(un)
symm4

start =('2000-01-01')
end =('2020-11-01')
c=pd.concat(web.DataReader(symm4,'yahoo-actions','2000-1-1','2020-11-1'))
c.to_excel('nasdaqqqc.xlsx')
# Out:
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OBAS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OBCI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OCC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OCFC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ODFL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ODP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OFIX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OLED', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OMEX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ONB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OPOF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ORLY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'ORRF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OSBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OSIS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OSUR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OTEX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OTTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'OVBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PAAS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PATK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PAYX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PBCT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PBHC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PCAR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PCH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PCTI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PCYG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PCYO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PDCE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PDCO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PDEX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PDLI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PEBK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PEBO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PEGA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PENN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PESI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PETS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PFBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PFBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PFBX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PFIN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PFSW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PGC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PGNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PICO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PKOH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PLAB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PLCE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PLPC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PLUG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PLUS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PLXS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PMD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PNBK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PNRG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'POOL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'POWI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'POWL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PPBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PPC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PRCP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'PRFT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
sympols4=pd.read_excel('./Downloads././Nasdaq.xlsx',sheet_name=4)

# %%
sympols3=pd.read_excel('./Downloads././N.xlsx',sheet_name=3)

# %%
start =('2000-01-01')
end =('2020-11-01')
x=pd.concat(web.DataReader(symm,'yahoo-actions','2000-1-1','2020-11-1'))
x.to_excel('nasdaqqq12.xlsx')
# Out:
# c:\users\rawan\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'CLRO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
sympols2=pd.read_excel('./Downloads././Nasdaq.xlsx',sheet_name=2)

# %%
sympols=pd.read_excel('./Downloads./Russell 20001.xlsx')

# %%
un=pd.unique(sympols['Symbol'])
symm=list(un)
symm
# Out:
# ['CAC',
#  'CACC',
#  'CACH',
#  'CAKE',
#  'CALM',
#  'CAMP',
#  'CAR',
#  'CARV',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATY',
#  'CBAN',
#  'CBRL',
#  'CBSH',
#  'CCBG',
#  'CCNE',
#  'CCUR',
#  'CDNS',
#  'CDZI',
#  'CECE',
#  'CENT',
#  'CENX',
#  'CERN',
#  'CERS',
#  'CETV',
#  'CFBK',
#  'CFFI',
#  'CFFN',
#  'CFNB',
#  'CGNX',
#  'CHCO',
#  'CHDN',
#  'CHKP',
#  'CHMG',
#  'CHNR',
#  'CHRW',
#  'CINF',
#  'CIZN',
#  'CLCT',
#  'CLDX',
#  'CLFD',
#  'CLRO',
#  'CLSN',
#  'CLWT',
#  'CMCO',
#  'CMCSA',
#  'CMCT',
#  'CMTL',
#  'CNBKA',
#  'CNMD',
#  'CNOB',
#  'CNTY',
#  'COHR',
#  'COHU',
#  'COKE',
#  'COLB',
#  'COLM',
#  'COST',
#  'CPRT',
#  'CPSS',
#  'CRAI',
#  'CREE',
#  'CRESY',
#  'CRMT',
#  'CRUS',
#  'CRVL',
#  'CRZO',
#  'CSCO',
#  'CSGP',
#  'CSGS',
#  'CSPI',
#  'CSWC',
#  'CTAS',
#  'CTBI',
#  'CTG',
#  'CTHR',
#  'CTIC',
#  'CTSH',
#  'CTXS',
#  'CU',
#  'CUBA',
#  'CVBF',
#  'CVCY',
#  'CVLY',
#  'CVTI',
#  'CVV',
#  'CWBC',
#  'CWCO',
#  'CWST',
#  'CYAN',
#  'CYBE',
#  'CYRN',
#  'CYTR',
#  'CZNC',
#  'DAIO',
#  'DAKT',
#  'DCOM',
#  'DENN',
#  'DGICB',
#  'DGII',
#  'DHIL',
#  'DIOD',
#  'DISH',
#  'DJCO',
#  'DLHC',
#  'DLTR',
#  'DMRC',
#  'DORM',
#  'DOX',
#  'DSGX',
#  'DSPG',
#  'DSWL',
#  'DVCR',
#  'DWSN',
#  'DXLG',
#  'DXPE',
#  'DXYN',
#  'DYNT',
#  'EA',
#  'EBAY',
#  'EBIX',
#  'ECOL',
#  'ECPG',
#  'ECTE',
#  'EDAP',
#  'EDUC',
#  'EEFT',
#  'EFOI',
#  'EGAN',
#  'EGBN',
#  'EGHT',
#  'EGOV',
#  'ELGX',
#  'ELSE',
#  'ELTK',
#  'EMCF',
#  'EMITF',
#  'EMKR',
#  'EML',
#  'EMMS',
#  'ENG',
#  'ENZN',
#  'EPAY',
#  'ERIC',
#  'ERIE',
#  'ESBK',
#  'ESCA',
#  'ESGR',
#  'ESLT',
#  'ESMC',
#  'ETFC',
#  'EVOL',
#  'EWBC',
#  'EXPD',
#  'EXPO',
#  'EXTR',
#  'EZPW']
