# %%
import pandas as pd

# %%
un=pd.read_excel('./Downloads/unemployment.xlsx')
un
# Out:
#     Year  Unemployment Rate (as of Dec.)  GDP Growth  Inflation (Dec. YOY)  \
# 0   2000                           0.039       0.041                 0.034
# 1   2001                           0.057       0.010                 0.016
# 2   2002                           0.060       0.017                 0.024
# 3   2003                           0.057       0.029                 0.019
# 4   2004                           0.054       0.038                 0.033
# 5   2005                           0.049       0.035                 0.034
# 6   2006                           0.044       0.029                 0.025
# 7   2007                           0.050       0.019                 0.041
# 8   2008                           0.073      -0.001                 0.001
# 9   2009                           0.099      -0.025                 0.027
# 10  2010                           0.093       0.026                 0.015
# ...
